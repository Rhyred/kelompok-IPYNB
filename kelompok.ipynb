# %%
# 18. Persentase per tahun
# ===============================
print("\n--- 18. Persentase Kontribusi per Tahun ---")

df['persentase_tahun'] = (
    df['jumlah_penderita_dm'] /
    df.groupby('tahun')['jumlah_penderita_dm'].transform('sum')
) * 100

print(df[['tahun', 'nama_kabupaten_kota',
          'jumlah_penderita_dm', 'persentase_tahun']].head())
# Out:
# --- 14. Total Penderita DM per Tahun ---
# tahun
# 2019     848455
# 2020    1078857
# 2021     925675
# 2022     644704
# 2023     645390
# 2024     668220
# Name: jumlah_penderita_dm, dtype: int64
#
# --- 15. Rata-rata Penderita DM per Kabupaten/Kota ---
# nama_kabupaten_kota
# KABUPATEN BANDUNG          51652.666667
# KABUPATEN BANDUNG BARAT    14246.333333
# KABUPATEN BEKASI           81174.333333
# KABUPATEN BOGOR            64286.500000
# KABUPATEN CIAMIS           38304.000000
# KABUPATEN CIANJUR          14363.166667
# KABUPATEN CIREBON          20553.333333
# KABUPATEN GARUT            20789.833333
# KABUPATEN INDRAMAYU        33056.666667
# KABUPATEN KARAWANG         92411.000000
# KABUPATEN KUNINGAN         21259.333333
# KABUPATEN MAJALENGKA       13028.333333
# KABUPATEN PANGANDARAN       7100.500000
# KABUPATEN PURWAKARTA       12953.500000
# KABUPATEN SUBANG           24120.166667
# KABUPATEN SUKABUMI         45277.500000
# KABUPATEN SUMEDANG         34894.000000
# ...

# %%
# Filter data tahun 2019
df_2019 = df[df['tahun'] == 2019]

# Ambil 10 kabupaten/kota dengan DM tertinggi
top_10_2019 = df_2019.sort_values(
    by='jumlah_penderita_dm',
    ascending=False
).head(10)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.barh(
    top_10_2019['nama_kabupaten_kota'],
    top_10_2019['jumlah_penderita_dm']
)
plt.xlabel('Jumlah Penderita')
plt.title('10 Kabupaten/Kota dengan Penderita DM Tertinggi (2019)')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
total_per_tahun = (
    df.groupby('tahun')['jumlah_penderita_dm']
    .sum()
    .reset_index()
)

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    total_per_tahun['tahun'],
    total_per_tahun['jumlah_penderita_dm'],
    marker='o'
)
plt.title('Tren Total Penderita DM di Jawa Barat')
plt.xlabel('Tahun')
plt.ylabel('Jumlah Penderita DM')
plt.grid(True)
plt.xticks(total_per_tahun['tahun'])
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
# Filter data tahun 2019
df_2019 = df[df['tahun'] == 2019]

plt.figure(figsize=(12, 6))
plt.bar(
    df_2019['nama_kabupaten_kota'],
    df_2019['jumlah_penderita_dm']
)
plt.xticks(rotation=90)
plt.xlabel('Kabupaten/Kota')
plt.ylabel('Jumlah Penderita DM')
plt.title('Jumlah Penderita DM per Kabupaten/Kota Tahun 2019')
plt.tight_layout()
plt.show()

# %%
# Total penderita per tahun (jadikan DataFrame)
total_per_tahun = (
    df.groupby('tahun')['jumlah_penderita_dm']
    .sum()
    .reset_index()
)

plt.figure(figsize=(10, 5))
plt.plot(
    total_per_tahun['tahun'],
    total_per_tahun['jumlah_penderita_dm'],
    marker='o'
)
plt.xlabel('Tahun')
plt.ylabel('Total Jumlah Penderita DM')
plt.title('Tren Total Jumlah Penderita DM di Jawa Barat')
plt.grid(True)
plt.xticks(total_per_tahun['tahun'])
plt.tight_layout()
plt.show()

# %%
# Ambil 10 kabupaten/kota dengan DM tertinggi tahun 2019
top_10_2019 = df_2019.sort_values(
    by='jumlah_penderita_dm',
    ascending=False
).head(10)

plt.figure(figsize=(10, 6))
plt.barh(
    top_10_2019['nama_kabupaten_kota'],
    top_10_2019['jumlah_penderita_dm']
)
plt.xlabel('Jumlah Penderita DM')
plt.title('10 Kabupaten/Kota dengan Penderita DM Tertinggi (2019)')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
# Pastikan kolom kategori_dm sudah ada
kategori_2019 = df_2019['kategori_dm'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(
    kategori_2019,
    labels=kategori_2019.index,
    autopct='%1.1f%%',
    startangle=90
)
plt.title('Proporsi Kategori Penderita DM Tahun 2019')
plt.tight_layout()
plt.show()

# %%
# Ambil 3 tahun terakhir yang tersedia
tahun_terakhir = sorted(df['tahun'].unique())[-3:]

data_3_tahun = total_per_tahun[
    total_per_tahun['tahun'].isin(tahun_terakhir)
]

plt.figure(figsize=(8, 5))
plt.bar(
    data_3_tahun['tahun'].astype(str),
    data_3_tahun['jumlah_penderita_dm']
)
plt.xlabel('Tahun')
plt.ylabel('Total Jumlah Penderita DM')
plt.title('Perbandingan Total Penderita DM (3 Tahun Terakhir)')
plt.tight_layout()
plt.show()
